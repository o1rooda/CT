# %% [markdown]
# K-평균 집군화

# %%
import os
import numpy as np
from numpy import *

def createDataSet():
    group = array([[1.0,1.1],[1.0,1.0],[0,0],[0,0.1]])
    labels = ['A','A','B','B']
    return group, labels

def classify0(inX, dataSet, labels, k):
    dataSetsize = dataSet.shape[0]
    diffMat = tile(inX, (dataSetSize, 1)) - dataSet
    sqDiffMat = diffMat**2
    sqDistances = sqDistances**0.5
    classCount = {}
    for i in range(k):
        voteIlabel = labels[sortedDistIndicies[i]]
        classCount[voteIlabel] = classCount.get(voteIlabel, 0) + 1
    sortedClassCount = sorted(classCount.iteritems(), key = operator.itemgetter(1), reverse = True)
    return sortedClassCount[0][0]

# %%
group = array([[1.0,1.1],[1.0,1.0],[0,0],[0,0.1]])
labels = ['A','A','B','B']
print group, labels
# Out:
# [[ 1.   1.1]
#  [ 1.   1. ]
#  [ 0.   0. ]
#  [ 0.   0.1]] ['A', 'A', 'B', 'B']

# %%
import os
from numpy import *
from os import listdir

#dir = os.getenv('HOME')+'/home/rooda/machinelearninginaction/Ch10/dataSet.txt'

def loadDataSet(filename):
    dataMat = []
    fr = open(filename)
    for line in fr.readlines():
        curLine = line.strip().split('\t')
        fltLine = map(float, curLine)
        dataMat.append(fltLine)
    return dataMat
    #print dataMat

#print len(dir)

# %%
test = loadDataSet('/home/rooda/rdClass/final/ggg.txt')
#print test
print len(test)
#print shape(test)[0]
# Out:
# 258

# %%
def distEclud(vecA, vecB):
    return sqrt(sum(power(vecA - vecB, 2)))

# %%
def randCent(dataSet, k):
    n = shape(dataSet)[1]
    centroids = mat(zeros((k,n)))
    for j in range(n):
        minJ = min(dataSet[:,j])
        print minJ
        rangeJ = float(max(dataSet[:,j]) - minJ)
        print rangeJ
        midCent = rangeJ * random.rand(k,1)
        print midCent
        centroids[:,j] = mat(minJ + midCent)
    return centroids

# %%
test = loadDataSet('/home/rooda/rdClass/final/ggg.txt')
dataMat = mat(test)
#pint dataMat
randCent(dataMat, 2)
# Out:
# matrix([[ 0.44552013,  0.73504251],
#         [ 0.33837898,  0.08739125]])

# %%
def distEclud(vecA, vecB):
    return sqrt(sum(power(vecA - vecB, 2)))

def randCent(dataSet, k):
    n = shape(dataSet)[1]
    centroids = mat(zeros((k,n)))
    for j in range(n):
        minJ = min(dataSet[:,j])
        #print minJ
        rangeJ = float(max(dataSet[:,j]) - minJ)
        #print rangeJ
        midCent = rangeJ * random.rand(k,1)
        #print midCent
        centroids[:,j] = mat(minJ + midCent)
    return centroids

def kMeans(dataSet, k, distMeas=distEclud, createCent=randCent):
    m = shape(dataSet)[0]
    #print m
    clusterAssment = mat(zeros((m,2)))
    #print clusterAssment
    centroids = createCent(dataSet, k)
    #print centroids
    clusterChanged = True
    while clusterChanged:
        clusterChanged = False
        for i in range(m):#for each data point assign it to the closest centroid
            minDist = inf; minIndex = -1
            for j in range(k):
                distJI = distMeas(centroids[j,:],dataSet[i,:])
                if distJI < minDist:
                    minDist = distJI; minIndex = j
            if clusterAssment[i,0] != minIndex: clusterChanged = True
            clusterAssment[i,:] = minIndex,minDist**2
       #print centroids
        for cent in range(k):#recalculate centroids
            ptsInClust = dataSet[nonzero(clusterAssment[:,0].A==cent)[0]]
            centroids[cent,:] = mean(ptsInClust, axis=0)
    return centroids, clusterAssment

# %%
test = loadDataSet('/home/rooda/rdClass/final/gbgb.txt')
dataMat = mat(test)
kMeans(dataMat, 4, distMeas=distEclud, createCent=randCent)
# Out:
# (matrix([[ 0.24921053,  0.44684211,  0.53      ,  0.75078947,  0.60710526],
#         [ 0.22027027,  0.32081081,  0.66594595,  0.29135135,  0.44054054],
#         [ 0.32981818,  0.29836364,  0.23581818,  0.26347273,  0.26490909],
#         [ 0.72      ,  0.428     ,  0.396     ,  0.55933333,  0.778     ]]),
#  matrix([[ 2.        ,  0.26411818],
#         [ 1.        ,  0.30136253],
#         [ 0.        ,  0.19157223],
#         [ 0.        ,  0.15137749],
#         [ 1.        ,  0.27612199],
#         [ 1.        ,  0.10358145],
#         [ 1.        ,  0.0945328 ],
#         [ 1.        ,  0.29290577],
#         [ 0.        ,  0.22343012],
#         [ 2.        ,  0.14688399],
#         [ 2.        ,  0.25134036],
#         [ 2.        ,  0.12766945],
#         [ 0.        ,  0.19613012],
#         [ 0.        ,  0.24697749],
#         [ 1.        ,  0.25320037],
#         [ 2.        ,  0.14763672],
#         [ 0.        ,  0.08558276],
#         [ 2.        ,  0.24899345],
#         [ 1.        ,  0.07476523],
#         [ 1.        ,  0.03439496],
#         [ 1.        ,  0.20302739],
#         [ 1.        ,  0.16829766],
#         [ 0.        ,  0.17384065],
#         [ 1.        ,  0.04466253],
#         [ 1.        ,  0.06427604],
#         [ 1.        ,  0.1768382 ],
#         [ 1.        ,  0.02320577],
#         [ 0.        ,  0.19339328],
#         [ 0.        ,  0.14738802],
#         [ 2.        ,  0.1700349 ],
#         [ 2.        ,  0.04491199],
#         [ 2.        ,  0.06801672],
#         [ 0.        ,  0.1356617 ],
#         [ 0.        ,  0.04757223],
#         [ 1.        ,  0.0631328 ],
#         [ 1.        ,  0.07131118],
#         [ 0.        ,  0.19130381],
#         [ 0.        ,  0.0567617 ],
#         [ 2.        ,  0.25515854],
#         [ 2.        ,  0.31788727],
#         [ 2.        ,  0.13566472],
#         [ 2.        ,  0.17359381],
#         [ 0.        ,  0.30959328],
#         [ 2.        ,  0.13616981],
#         [ 0.        ,  0.36445118],
#         [ 2.        ,  0.18556763],
#         [ 0.        ,  0.09676697],
#         [ 0.        ,  0.16659328],
#         [ 0.        ,  0.20899855],
#         [ 2.        ,  0.31067854],
#         [ 1.        ,  0.23525442],
#         [ 1.        ,  0.29761658],
#         [ 0.        ,  0.31487749],
#         [ 1.        ,  0.21692199],
#         [ 1.        ,  0.62531928],
#         [ 1.        ,  0.21213009],
#         [ 1.        ,  0.12565982],
#         [ 0.        ,  0.45874065],
#         [ 0.        ,  0.28277223],
#         [ 0.        ,  0.32160381],
#         [ 2.        ,  0.1454669 ],
#         [ 0.        ,  0.25926697],
#         [ 0.        ,  0.24028802],
#         [ 2.        ,  0.10828472],
#         [ 1.        ,  0.16581118],
#         [ 2.        ,  0.06046836],
#         [ 1.        ,  0.15701388],
#         [ 2.        ,  0.22166654],
#         [ 0.        ,  0.1200617 ],
#         [ 2.        ,  0.20232036],
#         [ 1.        ,  0.18578415],
#         [ 2.        ,  0.16529672],
#         [ 0.        ,  0.21623012],
#         [ 0.        ,  0.10198276],
#         [ 1.        ,  0.0877355 ],
#         [ 1.        ,  0.34278685],
#         [ 1.        ,  0.22940847],
#         [ 0.        ,  0.20275644],
#         [ 3.        ,  0.28629111],
#         [ 2.        ,  0.11528145],
#         [ 0.        ,  0.12944591],
#         [ 2.        ,  0.07994168],
#         [ 2.        ,  0.03006181],
#         [ 2.        ,  0.01781018],
#         [ 1.        ,  0.11920577],
#         [ 2.        ,  0.14711599],
#         [ 0.        ,  0.0925617 ],
#         [ 2.        ,  0.1511589 ],
#         [ 1.        ,  0.05732199],
#         [ 1.        ,  0.29972199],
#         [ 1.        ,  0.13807064],
#         [ 0.        ,  0.15604591],
#         [ 1.        ,  0.06330577],
#         [ 2.        ,  0.1046349 ],
#         [ 2.        ,  0.14771018],
#         [ 0.        ,  0.22784591],
#         [ 3.        ,  0.39757111],
#         [ 0.        ,  0.20620381],
#         [ 2.        ,  0.15791054],
#         [ 2.        ,  0.08432654],
#         [ 2.        ,  0.13330218],
#         [ 2.        ,  0.09491272],
#         [ 2.        ,  0.1668189 ],
#         [ 0.        ,  0.40407223],
#         [ 2.        ,  0.10306181],
#         [ 2.        ,  0.06724654],
#         [ 2.        ,  0.24419381],
#         [ 2.        ,  0.11443163],
#         [ 2.        ,  0.0776469 ],
#         [ 0.        ,  0.1714617 ],
#         [ 1.        ,  0.09769766],
#         [ 1.        ,  0.11636793],
#         [ 2.        ,  0.11745672],
#         [ 0.        ,  0.2928196 ],
#         [ 0.        ,  0.26321434],
#         [ 2.        ,  0.1501589 ],
#         [ 3.        ,  0.18264444],
#         [ 2.        ,  0.20502799],
#         [ 3.        ,  0.14446444],
#         [ 3.        ,  0.25399778],
#         [ 3.        ,  0.16799111],
#         [ 2.        ,  0.1607469 ],
#         [ 2.        ,  0.14379272],
#         [ 3.        ,  0.18824444],
#         [ 2.        ,  0.12810072],
#         [ 3.        ,  0.17477778],
#         [ 2.        ,  0.17825527],
#         [ 3.        ,  0.15619778],
#         [ 2.        ,  0.09751127],
#         [ 3.        ,  0.12005778],
#         [ 2.        ,  0.2024269 ],
#         [ 2.        ,  0.12123927],
#         [ 3.        ,  0.22890444],
#         [ 2.        ,  0.08251781],
#         [ 3.        ,  0.10318444],
#         [ 1.        ,  0.14678145],
#         [ 2.        ,  0.17105708],
#         [ 2.        ,  0.19092327],
#         [ 2.        ,  0.29548836],
#         [ 2.        ,  0.23398181],
#         [ 3.        ,  0.27630444],
#         [ 3.        ,  0.31622444],
#         [ 1.        ,  0.24475442],
#         [ 3.        ,  0.28187778],
#         [ 0.        ,  0.47330907]]))

# %%
def distEclud(vecA, vecB):
    return sqrt(sum(power(vecA - vecB, 2)))

def randCent(dataSet, k):
    n = shape(dataSet)[1]
    centroids = mat(zeros((k,n)))
    for j in range(n):
        minJ = min(dataSet[:,j])
        #print minJ
        rangeJ = float(max(dataSet[:,j]) - minJ)
        #print rangeJ
        midCent = rangeJ * random.rand(k,1)
        #print midCent
        centroids[:,j] = mat(minJ + midCent)
    return centroids

def kMeans(dataSet, k, distMeas=distEclud, createCent=randCent):
    m = shape(dataSet)[0]
    #print m
    clusterAssment = mat(zeros((m,2)))
    #print clusterAssment
    centroids = createCent(dataSet, k)
    #print centroids
    clusterChanged = True
    while clusterChanged:
        clusterChanged = False
        for i in range(m):#for each data point assign it to the closest centroid
            minDist = inf; minIndex = -1
            for j in range(k):
                distJI = distMeas(centroids[j,:],dataSet[i,:])
                if distJI < minDist:
                    minDist = distJI; minIndex = j
            if clusterAssment[i,0] != minIndex: clusterChanged = True
            clusterAssment[i,:] = minIndex,minDist**2
       #print centroids
        for cent in range(k):#recalculate centroids
            ptsInClust = dataSet[nonzero(clusterAssment[:,0].A==cent)[0]]#get all the point in this cluster
            centroids[cent,:] = mean(ptsInClust, axis=0) #assign centroid to mean 
    return centroids, clusterAssment

def biKmeans(dataSet, k, distMeas=distEclud):
    m = shape(dataSet)[0]
    clusterAssment = mat(zeros((m,2)))
    centroid0 = mean(dataSet, axis=0).tolist()[0]
    #print centroid0
    centList =[centroid0]
    #print centList
    for j in range(m):#calc initial Error
        clusterAssment[j,1] = distMeas(mat(centroid0), dataSet[j,:])**2
        #print clusterAssment[j,0]
    while (len(centList) < k):
        lowestSSE = inf
        for i in range(len(centList)):
            ptsInCurrCluster = dataSet[nonzero(clusterAssment[:,0].A==i)[0],:]
            #a = clusterAssment[:,0].A==i
            #print a
            #print nonzero(clusterAssment[:,0].A==i)[0]
            #print ptsInCurrCluster
            centroidMat, splitClustAss = kMeans(ptsInCurrCluster, 2, distMeas)
            #print splitClustAss
            sseSplit = sum(splitClustAss[:,1])
            #print sseSplit
            sseNotSplit = sum(clusterAssment[nonzero(clusterAssment[:,0].A!=i)[0],1])
            #print nonzero(clusterAssment[:,0].A!=i)
            print "sseSplit, and notSplit: ",sseSplit,sseNotSplit
            if (sseSplit + sseNotSplit) < lowestSSE:
                bestCentToSplit = i
                bestNewCents = centroidMat
                bestClustAss = splitClustAss.copy()
                lowestSSE = sseSplit + sseNotSplit
        bestClustAss[nonzero(bestClustAss[:,0].A == 1)[0],0] = len(centList) #change 1 to 3,4, or whatever
        bestClustAss[nonzero(bestClustAss[:,0].A == 0)[0],0] = bestCentToSplit
        print 'the bestCentToSplit is: ',bestCentToSplit
        print 'the len of bestClustAss is: ', len(bestClustAss)
        #print centList[bestCentToSplit]
        centList[bestCentToSplit] = bestNewCents[0,:].tolist()[0]
        #print centList[bestCentToSplit]
        #print bestNewCents[0,:].tolist()[0]
        centList.append(bestNewCents[1,:].tolist()[0])
        clusterAssment[nonzero(clusterAssment[:,0].A == bestCentToSplit)[0],:]= bestClustAss#reassign new clusters, and SSE
    return mat(centList), clusterAssment

# %%
test = loadDataSet('/home/rooda/rdClass/final/gbgb.txt')
dataMat = mat(test)
distMeas = distEclud
biKmeans(dataMat, 4, distMeas)
# Out:
# sseSplit, and notSplit:  33.0525337471 0.0
# the bestCentToSplit is:  0
# the len of bestClustAss is:  145
# sseSplit, and notSplit:
#  13.1589008485 16.4840561609
# sseSplit, and notSplit:
#  12.0530162557 16.5684775862
# the bestCentToSplit is:  1
# the len of bestClustAss is:  87
# sseSplit, and notSplit:
#  13.5446697115 12.0530162557
# sseSplit, and notSplit:  6.0106989881 21.4851532619
# sseSplit, and notSplit:
#  3.42103141026 23.7048181662
# the bestCentToSplit is:  0
# the len of bestClustAss is:  58
# (matrix([[ 0.34      ,  0.56846154,  0.55307692,  0.79538462,  0.575     ],
#         [ 0.3554    ,  0.2984    ,  0.2032    ,  0.28022   ,  0.31      ],
#         [ 0.18621622,  0.32108108,  0.62081081,  0.30243243,  0.24405405],
#         [ 0.408125  ,  0.315625  ,  0.505625  ,  0.5096875 ,  0.8165625 ]]),
#  matrix([[ 2.        ,  0.13760606],
#         [ 2.        ,  0.19642768],
#         [ 3.        ,  0.15080371],
#         [ 3.        ,  0.11390996],
#         [ 3.        ,  0.25099746],
#         [ 2.        ,  0.08336012],
#         [ 3.        ,  0.27274746],
#         [ 2.        ,  0.21291147],
#         [ 3.        ,  0.26487871],
#         [ 1.        ,  0.16792921],
#         [ 1.        ,  0.23580321],
#         [ 1.        ,  0.14295721],
#         [ 3.        ,  0.10498496],
#         [ 1.        ,  0.27247521],
#         [ 3.        ,  0.14819746],
#         [ 2.        ,  0.14281417],
#         [ 0.        ,  0.1566966 ],
#         [ 2.        ,  0.1297466 ],
#         [ 2.        ,  0.0533385 ],
#         [ 2.        ,  0.10364931],
#         [ 3.        ,  0.10944746],
#         [ 2.        ,  0.08681147],
#         [ 2.        ,  0.15646822],
#         [ 2.        ,  0.03839795],
#         [ 2.        ,  0.18349795],
#         [ 2.        ,  0.06008174],
#         [ 2.        ,  0.01903309],
#         [ 0.        ,  0.24615044],
#         [ 0.        ,  0.19813506],
#         [ 1.        ,  0.18191321],
#         [ 1.        ,  0.04467801],
#         [ 1.        ,  0.06804321],
#         [ 0.        ,  0.17572737],
#         [ 0.        ,  0.08458891],
#         [ 2.        ,  0.04935471],
#         [ 2.        ,  0.17610066],
#         [ 2.        ,  0.17062768],
#         [ 0.        ,  0.08514275],
#         [ 1.        ,  0.23767721],
#         [ 1.        ,  0.29310281],
#         [ 1.        ,  0.14982601],
#         [ 1.        ,  0.16921801],
#         [ 0.        ,  0.27253506],
#         [ 1.        ,  0.17284161],
#         [ 3.        ,  0.29875996],
#         [ 2.        ,  0.18320606],
#         [ 0.        ,  0.12395044],
#         [ 0.        ,  0.13911967],
#         [ 0.        ,  0.17405814],
#         [ 2.        ,  0.19326822],
#         [ 2.        ,  0.35378985],
#         [ 2.        ,  0.16628714],
#         [ 0.        ,  0.28118121],
#         [ 2.        ,  0.12177093],
#         [ 3.        ,  0.63089746],
#         [ 2.        ,  0.11106012],
#         [ 2.        ,  0.11962228],
#         [ 0.        ,  0.41042737],
#         [ 0.        ,  0.19065814],
#         [ 0.        ,  0.26797352],
#         [ 1.        ,  0.14007241],
#         [ 3.        ,  0.31408496],
#         [ 3.        ,  0.25894746],
#         [ 1.        ,  0.12004001],
#         [ 1.        ,  0.16501841],
#         [ 1.        ,  0.06871001],
#         [ 3.        ,  0.11560371],
#         [ 1.        ,  0.21986601],
#         [ 3.        ,  0.09832871],
#         [ 2.        ,  0.14216822],
#         [ 3.        ,  0.13177246],
#         [ 2.        ,  0.1067412 ],
#         [ 3.        ,  0.05921621],
#         [ 0.        ,  0.18101198],
#         [ 2.        ,  0.09004931],
#         [ 3.        ,  0.23744121],
#         [ 2.        ,  0.19401417],
#         [ 3.        ,  0.22340371],
#         [ 3.        ,  0.11659121],
#         [ 1.        ,  0.08689041],
#         [ 3.        ,  0.17289746],
#         [ 1.        ,  0.10238177],
#         [ 1.        ,  0.05479081],
#         [ 1.        ,  0.02617801],
#         [ 1.        ,  0.13347761],
#         [ 1.        ,  0.15247641],
#         [ 3.        ,  0.14743496],
#         [ 2.        ,  0.10195741],
#         [ 2.        ,  0.04583579],
#         [ 3.        ,  0.11432246],
#         [ 2.        ,  0.10156282],
#         [ 2.        ,  0.16011958],
#         [ 2.        ,  0.06939255],
#         [ 1.        ,  0.13469921],
#         [ 1.        ,  0.15658201],
#         [ 0.        ,  0.20826583],
#         [ 3.        ,  0.30740371],
#         [ 0.        ,  0.17086583],
#         [ 1.        ,  0.16664841],
#         [ 1.        ,  0.07696001],
#         [ 1.        ,  0.09916921],
#         [ 1.        ,  0.07997281],
#         [ 1.        ,  0.13165161],
#         [ 0.        ,  0.45765814],
#         [ 1.        ,  0.12233881],
#         [ 1.        ,  0.07195801],
#         [ 1.        ,  0.20774801],
#         [ 1.        ,  0.08102561],
#         [ 1.        ,  0.06454641],
#         [ 0.        ,  0.14677352],
#         [ 2.        ,  0.1201466 ],
#         [ 2.        ,  0.08699525],
#         [ 1.        ,  0.12494921],
#         [ 0.        ,  0.20121967],
#         [ 0.        ,  0.15970429],
#         [ 1.        ,  0.13264761],
#         [ 3.        ,  0.31022871],
#         [ 1.        ,  0.17609361],
#         [ 3.        ,  0.24489121],
#         [ 0.        ,  0.41666583],
#         [ 3.        ,  0.40209121],
#         [ 1.        ,  0.18346241],
#         [ 1.        ,  0.13289081],
#         [ 3.        ,  0.17927871],
#         [ 1.        ,  0.13034561],
#         [ 3.        ,  0.38004121],
#         [ 1.        ,  0.15541761],
#         [ 3.        ,  0.40738496],
#         [ 1.        ,  0.11765321],
#         [ 3.        ,  0.28951621],
#         [ 1.        ,  0.17702441],
#         [ 1.        ,  0.09435001],
#         [ 0.        ,  0.30681198],
#         [ 1.        ,  0.08293641],
#         [ 3.        ,  0.16853496],
#         [ 2.        ,  0.17319255],
#         [ 1.        ,  0.15685161],
#         [ 1.        ,  0.17587241],
#         [ 1.        ,  0.26771801],
#         [ 1.        ,  0.22846081],
#         [ 3.        ,  0.51204121],
#         [ 0.        ,  0.40102737],
#         [ 2.        ,  0.27526822],
#         [ 0.        ,  0.23167352],
#         [ 0.        ,  0.31956583]]))
